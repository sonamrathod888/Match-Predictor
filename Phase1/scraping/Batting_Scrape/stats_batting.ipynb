# %%
import pandas as pd

df = pd.read_csv("all_teams_batting_1.csv")
#df.head()
# Out:
#        player_name  matches_played innings_batted not_outs runs_scored  \
# 0       P Amarnath               6              -        -           -
# 1       S Anirudha              19             12        5         133
# 2  KB Arun Karthik               1              1        1           3
# 3         R Ashwin              97             31       11         190
# 4          KM Asif               2              -        -           -
#
#   highest_inns_score batting_average balls_faced batting_strike_rate  \
# 0                  -               -           -                   -
# 1                 64              19         108              123.14
# 2                 3*               -           5                  60
# 3                 23             9.5         202               94.05
# 4                  -               -           -                   -
#
#   hundreds_scored fifties_scored duckes_scored boundary_fours boundary_sixes  \
# ...

# %%
df.dtypes
# Out:
# player_name            object
# matches_played          int64
# innings_batted         object
# not_outs               object
# runs_scored            object
# highest_inns_score     object
# batting_average        object
# balls_faced            object
# batting_strike_rate    object
# hundreds_scored        object
# fifties_scored         object
# duckes_scored          object
# boundary_fours         object
# boundary_sixes         object
# times_out              object
# dtype: object

# %%
i = df[df.runs_scored=='-'].index

# %%
i
# Out:
# Int64Index([  0,   4,   5,  20,  23,  37,  47,  50,  52,  57,  62,  70,  79,
#             126, 132, 138, 145, 148, 151, 158, 172, 179, 189, 215, 217, 224,
#             238, 242, 263, 267, 272, 282, 290, 308, 310, 365, 374, 397, 403,
#             451, 465, 477, 491, 501, 514, 549, 552, 556, 577, 579, 590, 598,
#             608, 609, 640, 651, 668, 676, 677, 679, 685, 702, 704, 743, 761,
#             784, 801, 811, 818, 821, 840, 863, 865, 868, 891, 900, 921],
#            dtype='int64')

# %%
j=df[df.balls_faced=='-'].index

# %%
j
# Out:
# Int64Index([  0,   4,   5,  20,  23,  37,  47,  50,  52,  57,  62,  70,  79,
#             126, 132, 138, 145, 148, 151, 158, 172, 179, 189, 215, 217, 224,
#             238, 242, 263, 267, 272, 282, 290, 308, 310, 365, 374, 397, 403,
#             451, 465, 477, 491, 501, 514, 549, 552, 556, 577, 579, 590, 598,
#             608, 609, 640, 651, 668, 676, 677, 679, 685, 702, 704, 743, 761,
#             784, 801, 811, 818, 821, 840, 863, 865, 868, 891, 900, 921],
#            dtype='int64')

# %%
i==j
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
k=df[df.times_out=='#VALUE!'].index

# %%
k
# Out:
# Int64Index([  0,   4,   5,  20,  23,  37,  47,  50,  52,  57,  62,  70,  79,
#             126, 132, 138, 145, 148, 151, 158, 172, 179, 189, 215, 217, 224,
#             238, 242, 263, 267, 272, 282, 290, 308, 310, 365, 374, 397, 403,
#             451, 465, 477, 491, 501, 514, 549, 552, 556, 577, 579, 590, 598,
#             608, 609, 640, 651, 668, 676, 677, 679, 685, 702, 704, 743, 761,
#             784, 801, 811, 818, 821, 840, 863, 865, 868, 891, 900, 921],
#            dtype='int64')

# %%
k==i
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
df.drop(i,inplace=True)

# %%
df['runs_scored']=df['runs_scored'].astype('int64')
df['balls_faced']=df['balls_faced'].astype('int64')
df['times_out']=df['times_out'].astype('int64')

# %%
df.dtypes
# Out:
# player_name            object
# matches_played          int64
# innings_batted         object
# not_outs               object
# runs_scored             int64
# highest_inns_score     object
# batting_average        object
# balls_faced             int64
# batting_strike_rate    object
# hundreds_scored        object
# fifties_scored         object
# duckes_scored          object
# boundary_fours         object
# boundary_sixes         object
# times_out               int64
# dtype: object

# %%
res = df.groupby('player_name').agg({'runs_scored':'sum','balls_faced':'sum','times_out':'sum'}).reset_index()

# %%
res
# Out:
#               player_name  runs_scored  balls_faced  times_out
# 0          A Ashish Reddy          280          193         15
# 1              A Chandila            4            7          0
# 2                A Chopra           53           71          6
# 3             A Choudhary           25           20          1
# 4             A Dananjaya            4            5          0
# 5              A Flintoff           62           53          2
# 6                A Kumble           35           47          3
# 7                A Mishra          341          365         29
# 8                A Mithun           34           26          5
# 9                A Mukund           19           22          2
# 10                A Nehra           41           62          7
# 11                  A Nel            0            0          1
# 12                A Singh            2           10          4
# 13              A Symonds          974          750         27
# ...

# %%
# idx=0
# new=df['player_name']
# res.insert(loc=idx,column='player_name',value=new)

# %%
res
# Out:
#               player_name  runs_scored  balls_faced  times_out
# 0          A Ashish Reddy          280          193         15
# 1              A Chandila            4            7          0
# 2                A Chopra           53           71          6
# 3             A Choudhary           25           20          1
# 4             A Dananjaya            4            5          0
# 5              A Flintoff           62           53          2
# 6                A Kumble           35           47          3
# 7                A Mishra          341          365         29
# 8                A Mithun           34           26          5
# 9                A Mukund           19           22          2
# 10                A Nehra           41           62          7
# 11                  A Nel            0            0          1
# 12                A Singh            2           10          4
# 13              A Symonds          974          750         27
# ...

# %%
res.to_csv('stats_batting.csv',index=False)
